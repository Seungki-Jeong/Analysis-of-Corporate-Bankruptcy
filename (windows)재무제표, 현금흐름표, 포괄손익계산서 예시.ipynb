# %%
import dart_fss as dart
import pandas as pd

# %%
api_key='7bba91f51399cd6256c184c5ad0b2539c0bfd8b6'
dart.set_api_key(api_key=api_key)
# Out:
# '7bba91f51399cd6256c184c5ad0b2539c0bfd8b6'

# %%
crp_list = dart.get_corp_list()
# Out:
# Output()
# Output()
# Output()

# %%
crp_list.find_by_product(product='제조', market='K')
# Out:
# [[00293886]위닉스,
#  [00153375]태광,
#  [00257732]한국정밀기계,
#  [00618410]상상인인더스트리,
#  [00186452]바른테크놀로지,
#  [00442905]대성파인텍,
#  [00353018]슈펙스비앤피,
#  [01090471]씨아이에스,
#  [00138747]아세아텍,
#  [00155692]우리조명,
#  [00409681]아스트,
#  [00172079]파나진,
#  [00240857]바이오스마트,
#  [00531865]유니테크노,
#  [00216498]성도이엔지,
#  [00497631]티플랙스,
#  [00608316]대한과학,
#  [00811372]노바렉스,
#  [00531917]톱텍,
#  [00825959]하이비젼시스템,
#  [00617314]타이거일렉,
#  [01203808]AP시스템,
#  [01071944]미래생명자원,
#  [00363486]로체시스템즈,
#  [00166528]서암기계공업,
#  [00599285]서플러스글로벌,
#  [00351579]SGA,
#  [00124276]부스타,
#  [00406329]루멘스,
#  [00530556]예스티,
#  [01089350]켐트로스,
#  [00298377]아이씨디,
#  [00536523]로보스타,
#  [00231831]조아제약,
#  [00813389]베셀,
#  [00580056]스맥,
#  [00358271]에스에프에이,
#  [00602172]와이엠티,
#  [01108442]에치에프알,
#  [00480367]삼강엠앤티,
#  [00411385]유비쿼스홀딩스,
#  [00407285]아이컴포넌트,
#  [00610083]비아트론,
#  [00230911]HRS,
#  [00913689]세경하이테크,
#  [00155735]피제이전자,
#  [00245472]티씨케이,
#  [00442570]제우스,
#  [00484682]엘오티베큠,
#  [00255044]현대통신,
#  [00108490]엔피케이,
# ...

# %%
len(crp_list.find_by_product(product='제조', market='K'))
# Out:
# 84

# %%
# import re
# remove_text = 'asdf(asdf123213)'

# print(re.sub(r'\([^)]*\)', '', remove_text))

# 출력 결과 : 'asdf'
# Out:
# asdf

# %%
pr= pd.DataFrame(crp_list.find_by_product(product='제조', market='K'))
pr.columns = (['name'])
pr['name'] = pr['name'].astype(str)
pr['name'] = pr['name'].str.split("]").str[1]
pr
# Out:
#         name
# 0        위닉스
# 1         태광
# 2     한국정밀기계
# 3   상상인인더스트리
# 4    바른테크놀로지
# ..       ...
# 79     세운메디칼
# 80    에이프런티어
# 81      동국산업
# 82      아이원스
# 83   에프엔에스테크
#
# [84 rows x 1 columns]

# %%
pr.to_csv("data/kosdaq.csv", index=False)

# %%
pd.read_csv("data/kosdaq.csv")
# Out:
#         name
# 0        위닉스
# 1         태광
# 2     한국정밀기계
# 3   상상인인더스트리
# 4    바른테크놀로지
# ..       ...
# 79     세운메디칼
# 80    에이프런티어
# 81      동국산업
# 82      아이원스
# 83   에프엔에스테크
#
# [84 rows x 1 columns]

# %%
crp_list.find_by_sector('제조')
# Out:
# [[00956028]엑세스바이오,
#  [00112165]디아이씨,
#  [00103510]인지컨트롤스,
#  [00186799]태웅,
#  [00390365]토비스,
#  [00126380]삼성전자,
#  [00293886]위닉스,
#  [00134723]페이퍼코리아,
#  [00208444]피에스케이홀딩스,
#  [00150165]브이티지엠피,
#  [00125965]삼본전자,
#  [00815369]에스제이엠,
#  [00440712]WI,
#  [00102113]경인양행,
#  [00569646]영우디에스피,
#  [00127158]씨아이테크,
#  [00192499]팜스토리,
#  [00153375]태광,
#  [00124726]빙그레,
#  [00149804]대유에이텍,
#  [00305297]코텍,
#  [00910840]윈하이텍,
#  [00617998]세원,
#  [00453929]메디포스트,
#  [00132318]성광벤드,
#  [00620558]에이비프로바이오,
#  [00110608]DSR,
#  [00157681]롯데정밀화학,
#  [00351630]세코닉스,
#  [01047451]셀바스헬스케어,
#  [00117300]TCC스틸,
#  [00146861]자화전자,
#  [00260383]대한유화,
#  [00311270]원텍,
#  [00137012]에스앤더블류,
#  [00257732]한국정밀기계,
#  [00378628]KH바텍,
#  [00175173]오스템,
#  [00132992]성우하이텍,
#  [00103547]우진비앤지,
#  [00125150]삼광글라스,
#  [00145163]파미셀,
#  [00203023]시노펙스,
#  [00156150]하이트론씨스템즈,
#  [00114154]덕양산업,
#  [00492353]파이오링크,
#  [00205003]좋은사람들,
#  [00164788]현대모비스,
#  [00157636]케이피에프,
#  [00145914]인터엠,
#  [00159564]한국주강,
# ...

# %%
com = pd.read_csv('data/com_list.csv')
com
# Out:
#         company      date
# 0          데코앤이  20191120
# 1            신텍  20180709
# 2         금오하이텍  20170607
# 3        에이치앤아이  20160714
# 4         티에스엠텍  20150520
# ..          ...       ...
# 504  홍익엔지니어링(주)  20190402
# 505     홍주실업(주)  20181024
# 506     화신산업(주)  20191126
# 507   효진종합건설(주)  20181204
# 508        JS무역  20180907
#
# [509 rows x 2 columns]

# %%
c = []

# %%
# a = ['삼성전자']
# b = ['20191231', '20181231', '20171231']
# for i in a:
#     basic_info = crp_list.find_by_corp_name(i, exactly=True)[0]

# %%
basic_info = crp_list.find_by_corp_name('이매진아시아', exactly=True)[0]

# %%
fs = basic_info.extract_fs(bgn_de='20191231')
# Out:
# Output()
# Output()
# ...

# %%
# 'bs' 재무상태표, 'is' 손익계산서, 'cis' 포괄손익계산서, 'cf' 현금흐름표
df_cis = fs['cis']
df_bs = fs['bs']
df_cf = fs['cf']

# %%
df_cis.drop(['20180101-20181231', '20170101-20171231'], axis=1)
# Out:
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    [D431410] Statement of comprehensive income, by function of expense - Consolidated financial statements (Unit: KRW)  \
#                                                                                                             concept_id
# 0                                   ifrs-full_Revenue
# 1                               ifrs-full_CostOfSales
# 2                               ifrs-full_GrossProfit
# 3      dart_TotalSellingGeneralAdministrativeExpenses
# 4                            dart_OperatingIncomeLoss
# 5                                     dart_OtherGains
# 6   dart_GainsOnValuationOfLongTermFinancialInstru...
# 7           dart_GainsOnSaleOfInvestmentsInAssociates
# ...

# %%
df_bs.drop(['20181231', '20171231'], axis=1)
# Out:
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    [D220000] Statement of financial position, order of liquidity - Consolidated financial statements (Unit: KRW)  \
#                                                                                                       concept_id
# 0                    ifrs-full_CashAndCashEquivalents
# 1   dart_ShortTermDepositsNotClassifiedAsCashEquiv...
# 2           ifrs-full_TradeAndOtherCurrentReceivables
# 3                          ifrs-full_CurrentTaxAssets
# 4                               ifrs-full_Inventories
# 5                             dart_OtherCurrentAssets
# 6   dart_LongTermDepositsNotClassifiedAsCashEquiva...
# 7   dart_LongTermTradeAndOtherNonCurrentReceivable...
# 8                 ifrs-full_PropertyPlantAndEquipment
# ...

# %%
df_cf.drop(['20180101-20181231', '20170101-20171231'], axis=1)
# Out:
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    [D520000] Statement of cash flows, indirect method - Consolidated financial statements (Unit: KRW)  \
#                                                                                            concept_id
# 0    ifrs-full_CashFlowsFromUsedInOperatingActivities
# 1              dart_ProfitLossForStatementOfCashFlows
# 2         ifrs-full_AdjustmentsForReconcileProfitLoss
# 3   dart_AdjustmentsForAssetsLiabilitiesOfOperatin...
# 4   ifrs-full_InterestReceivedClassifiedAsOperatin...
# 5   ifrs-full_InterestPaidClassifiedAsOperatingAct...
# 6   ifrs-full_IncomeTaxesPaidRefundClassifiedAsOpe...
# 7    ifrs-full_CashFlowsFromUsedInInvestingActivities
# 8   dart_ProceedsFromSalesOfShortTermFinancialInst...
# ...
